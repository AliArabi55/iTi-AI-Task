# %% [markdown]
# <a href="https://colab.research.google.com/github/AliArabi55/iTi-AI-Task/blob/add-notebook-solution/ITI_DataPrepPython_Day3_SummerTraining_2024_SOLVED_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center><h1><b><font size='10px'> Data Preparation Using Python - Part II </center></h1></b>
# <hr>

# %% [markdown]
# **In today's session, our main focus will be on**
#   *  developing proficiency in working with multiple datasets using pandas.
#   *  techniques for combining, joining, and manipulating DataFrames.

# %% [markdown]
# ## 📍 **Concatenating DataFrames**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; combining multiple data frames either vertically (row-wise) or horizontally (column-wise)

# %% [markdown]
# > ### ✍🏻 **Vertical Concatenation**
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

df_concat = pd.concat([df1, df2], axis=0)

print(df_concat)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df2
# Out:
#    A  B
# 0  5  7
# 1  6  8

# %%
# Concatenate vertically (row-wise)
concatenated_df = pd.concat([df1, df2], axis=0)

# Display the concatenated dataframe
concatenated_df
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %% [markdown]
# > ### ✍🏻 **Horizontal Concatenation**
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df3 = pd.DataFrame({'C': [5, 6], 'D': [7, 8]})

df_concat = pd.concat([df1, df3], axis=1)

print(df_concat)
# Out:
#    A  B  C  D
# 0  1  3  5  7
# 1  2  4  6  8

# %% [markdown]
# ## 📍 **Joining DataFrames**

# %% [markdown]
# > ### ✍🏻 **INNER JOIN:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; returns only the matching records from both tables based on a common key column.

# %% [markdown]
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ![capture9-7.png](data:image/png;base64,...)

# %%
import pandas as pd

# Sample dataframes
df1 = pd.DataFrame({'ID': [1, 2, 3, 4],
                    'Name': ['John', 'Alice', 'Bob', 'Emily']})

df2 = pd.DataFrame({'ID': [1, 4, 5, 6],
                    'Age': [25, 32, 41, 27]})

# %%
df1
# Out:
#    ID   Name
# 0   1   John
# 1   2  Alice
# 2   3    Bob
# 3   4  Emily

# %%
df2
# Out:
#    ID  Age
# 0   1   25
# 1   4   32
# 2   5   41
# 3   6   27

# %%
# Inner join based on 'ID' column
inner_join_df = pd.merge(df1, df2, on='ID', how='inner')

# Display the resulting dataframe
print(inner_join_df)
# Out:
#    ID   Name  Age
# 0   1   John   25
# 1   4  Emily   32

# %% [markdown]
# > ###  ✍🏻 **LEFT JOIN:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; returns all records from the left table and the matching records from the right table.

# %% [markdown]
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ![capture9-7 (1).png](data:image/png;base64,...)

# %%
# Left join based on 'ID' column
left_join_df = pd.merge(df1, df2, on='ID', how='left')

# Display the resulting dataframe
print(left_join_df)
# Out:
#    ID   Name   Age
# 0   1   John  25.0
# 1   2  Alice   NaN
# 2   3    Bob   NaN
# 3   4  Emily  32.0

# %% [markdown]
# > ###  ✍🏻 **RIGHT JOIN:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; returns all records from the right table and the matching records from the left table

# %% [markdown]
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;![333.png](data:image/png;base64,...)

# %%
# Right join based on 'ID' column
right_join_df = pd.merge(df1, df2, on='ID', how='right')

# Display the resulting dataframe
print(right_join_df)
# Out:
#    ID   Name  Age
# 0   1   John   25
# 1   4  Emily   32
# 2   5    NaN   41
# 3   6    NaN   27

# %% [markdown]
# > ###  ✍🏻 **FULL/OUTER JOIN:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; returns all records from both tables, combining the records from the left and right tables.

# %% [markdown]
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ![444.png](data:image/png;base64,...)

# %%
# Outer join based on 'ID' column
outer_join_df = pd.merge(df1, df2, on='ID', how='outer')

# Display the resulting dataframe
print(outer_join_df)
# Out:
#    ID   Name   Age
# 0   1   John  25.0
# 1   2  Alice   NaN
# 2   3    Bob   NaN
# 3   4  Emily  32.0
# 4   5    NaN  41.0
# 5   6    NaN  27.0

# %% [markdown]
# ## 📍 **Exploring and Manipulating Data <font size='4.5px' color='blue'>(Advanced Techniques)**

# %% [markdown]
# > ### ✍🏻 **GroupBy:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Allows you to group data based on one or more columns.

# %%
df = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 15, 20, 50, 30]
})
df
# Out:
#   Category  Value
# 0        A     10
# 1        B     15
# 2        A     20
# 3        B     50
# 4        A     30

# %%
import pandas as pd

# Sample dataframe


# Grouping by 'Category' and calculating the mean
grouped_df = df.groupby('Category').mean()

# Display the grouped dataframe
print(grouped_df)
# Out:
#           Value
# Category
# A          20.0
# B          32.5

# %% [markdown]
# > ### ✍🏻 **Agg:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; It allows you to apply multiple aggregation functions simultaneously.

# %%
import pandas as pd

# Sample dataframe
df = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 15, 20, 25, 30]
})

# Applying multiple aggregation functions using agg
aggregated_df = df.groupby('Category')['Value'].agg(['sum', 'mean', 'max'])

# Display the aggregated dataframe
print(aggregated_df)
# Out:
#           sum  mean  max
# Category
# A          60  20.0   30
# B          40  20.0   25

# %% [markdown]
# > ### ✍🏻 **Where:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Replace values based on a specified condition.

# %%
import numpy as np

# Sample dataframe
df = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 15, 20, 25, 30]
})

# Applying a condition to replace values
df['New_Value'] = np.where(df['Value'] > 20, 'High', 'Low')

# Display the updated dataframe
print(df)
# Out:
#   Category  Value New_Value
# 0        A     10       Low
# 1        B     15       Low
# 2        A     20       Low
# 3        B     25      High
# 4        A     30      High

# %% [markdown]
# > ### ✍🏻 **Filter:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Subset the dataframe rows or columns according to the specified index labels.
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp;  Filters groups based on a condition and returns the filtered groups.

# %%
import pandas as pd
import numpy as np


df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  index=['mouse', 'rabbit'],
                  columns=['one', 'two', 'three'])
df
# Out:
#         one  two  three
# mouse     1    2      3
# rabbit    4    5      6

# %%
# select columns by regular expression
df.filter(regex='e$', axis=1)
# Out:
#           one three
# mouse       1     3
# rabbit  amani    wa

# %%
import pandas as pd

# Sample dataframe
df = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B', 'A', 'C'],
    'Value': [10, 15, 20, 25, 30, 40]
})

# Filtering rows based on a condition
filtered_df = df.groupby('Category').filter(lambda x: len(x) > 2)

# Display the filtered dataframe
print(filtered_df)
# Out:
#   Category  Value
# 0        A     10
# 1        A     15
# 4        A     30

# %% [markdown]
# > ### ✍🏻 **Apply:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Allows you to apply a `custom function` to each row or column of a dataframe,
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Providing a flexible way to perform element-wise operations and transformations on the data.

# %%
# Sample dataframe
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave'],
    'Age': [25, 30, 35, 40],
    'Salary': [15000, 30000, 70000, 80000]
})
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   15000
# 1      Bob   30   30000
# 2  Charlie   35   70000
# 3     Dave   40   80000

# %%
import pandas as pd



# Applying a custom function to calculate bonus
def calculate_bonus(row):
    if row['Age'] <= 30:
        return row['Salary'] * 0.1
    else:
        return row['Salary'] * 0.05

# Applying the custom function to each row
df['Bonus'] = df.apply(calculate_bonus, axis=1)

# Display the updated dataframe
print(df)
# Out:
#       Name  Age  Salary   Bonus
# 0    Alice   25   15000  1500.0
# 1      Bob   30   30000  3000.0
# 2  Charlie   35   70000  3500.0
# 3     Dave   40   80000  4000.0

# %% [markdown]
# > ### ✍🏻 **Pivot Table:**
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; Creates a spreadsheet-style pivot table based on the data.
#
# &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; ✦ &nbsp; It allows you to summarize and analyze data from different perspectives.

# %%
import pandas as pd

# Sample dataset
data = {
    'City': ['New York', 'London', 'Tokyo', 'New York', 'London', 'Tokyo'],
    'Year': [2018, 2018, 2018, 2019, 2019, 2019],
    'Population': [8623000, 8908081, 9273000, 8399000, 9304015, 9432000]
}

df = pd.DataFrame(data)
df
# Out:
#        City  Year  Population
# 0  New York  2018     8623000
# 1    London  2018     8908081
# 2     Tokyo  2018     9273000
# 3  New York  2019     8399000
# 4    London  2019     9304015
# 5     Tokyo  2019     9432000

# %%
# Creating a pivot table
pivot_table = df.pivot_table(index='City', columns='Year', values='Population', aggfunc='sum')

# Display the original table
print(df)

print('-----------------------------')

# Display the pivot table
print(pivot_table)
# Out:
#        City  Year  Population
# 0  New York  2018     8623000
# 1    London  2018     8908081
# 2     Tokyo  2018     9273000
# 3  New York  2019     8399000
# 4    London  2019     9304015
# 5     Tokyo  2019     9432000
# -----------------------------
# Year         2018     2019
# City
# London    8908081  9304015
# New York  8623000  8399000
# Tokyo     9273000  9432000

# %%
import pandas as pd
pd.read_csv("clv_data.csv")
# Out:
#       Unnamed: 0    id   age  gender  income  days_on_platform           city  \
# 0              0     0   NaN    Male  126895              14.0  San Francisco
# 1              1     1   NaN    Male  161474              14.0          Tokyo
# 2              2     2  24.0    Male  104723              34.0         London
# 3              3     3  29.0    Male   43791              28.0         London
# 4              4     4  18.0  Female  132181              26.0         London
# ...          ...   ...   ...     ...     ...               ...            ...
# 4995        4995  4995   NaN  Female  212261              28.0  San Francisco
# 4996        4996  4996   NaN    Male   70228              12.0  San Francisco
# 4997        4997  4997   NaN    Male   64995              14.0  New York City
# 4998        4998  4998   NaN    Male   56144               4.0  New York City
# 4999        4999  4999   NaN  Female  110977              29.0         London
#
#       purchases
# ...
